# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def info(df):
    print(f"SHAPE OF THE DATA: {df.shape}")
    print(f"The dataframe has {len(df.columns)} columns")
    numeric_columns = df.select_dtypes(include=['number']).columns
    print(f"The dataframe has {len(numeric_columns)} numeric columns")
    categorical_columns = df.select_dtypes(exclude=['number']).columns
    print(f"The dataframe has {len(categorical_columns)} categorical columns")
    print("Null Values")
    null_counts = df.isnull().sum()
    if not null_counts.empty:
        print(null_counts)

# %%
attend_raw = pd.read_csv('../dataset/nfl_data/attendance.csv')
attend_raw
# Out:
#              team  team_name  year    total    home    away  week  \
# 0         Arizona  Cardinals  2000   893926  387475  506451     1
# 1         Arizona  Cardinals  2000   893926  387475  506451     2
# 2         Arizona  Cardinals  2000   893926  387475  506451     3
# 3         Arizona  Cardinals  2000   893926  387475  506451     4
# 4         Arizona  Cardinals  2000   893926  387475  506451     5
# ...           ...        ...   ...      ...     ...     ...   ...
# 10841  Washington   Redskins  2019  1101466  523906  577560    13
# 10842  Washington   Redskins  2019  1101466  523906  577560    14
# 10843  Washington   Redskins  2019  1101466  523906  577560    15
# 10844  Washington   Redskins  2019  1101466  523906  577560    16
# 10845  Washington   Redskins  2019  1101466  523906  577560    17
#
#        weekly_attendance
# 0                77434.0
# 1                66009.0
# 2                    NaN
# 3                71801.0
# 4                66985.0
# ...

# %%
attend_raw.isnull().sum()
# Out:
# team                   0
# team_name              0
# year                   0
# total                  0
# home                   0
# away                   0
# week                   0
# weekly_attendance    638
# dtype: int64

# %%
len(attend_raw['year'].unique())
# attend_raw['week'].unique()
# Out:
# 20

# %%
attend_raw = pd.DataFrame(attend_raw)
attend_raw
# Out:
#              team  team_name  year    total    home    away  week  \
# 0         Arizona  Cardinals  2000   893926  387475  506451     1
# 1         Arizona  Cardinals  2000   893926  387475  506451     2
# 2         Arizona  Cardinals  2000   893926  387475  506451     3
# 3         Arizona  Cardinals  2000   893926  387475  506451     4
# 4         Arizona  Cardinals  2000   893926  387475  506451     5
# ...           ...        ...   ...      ...     ...     ...   ...
# 10841  Washington   Redskins  2019  1101466  523906  577560    13
# 10842  Washington   Redskins  2019  1101466  523906  577560    14
# 10843  Washington   Redskins  2019  1101466  523906  577560    15
# 10844  Washington   Redskins  2019  1101466  523906  577560    16
# 10845  Washington   Redskins  2019  1101466  523906  577560    17
#
#        weekly_attendance
# 0                77434.0
# 1                66009.0
# 2                    NaN
# 3                71801.0
# 4                66985.0
# ...

# %%
info(attend_raw)
# Out:
# SHAPE OF THE DATA: (10846, 8)
# The dataframe has 8 columns
# The dataframe has 6 numeric columns
# The dataframe has 2 categorical columns
# Null Values
# team                   0
# team_name              0
# year                   0
# total                  0
# home                   0
# away                   0
# week                   0
# weekly_attendance    638
# dtype: int64

# %%
game_raw['home_team'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\fins6\Documents\ML_study\kaggle_ML\code\nfl.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/fins6/Documents/ML_study/kaggle_ML/code/nfl.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> game_raw['home_team'].unique()
#
# NameError: name 'game_raw' is not defined

# %%
game_raw = pd.read_csv('../dataset/nfl_data/games.csv')
game_raw
# Out:
#       year       week            home_team            away_team  \
# 0     2000          1    Minnesota Vikings        Chicago Bears
# 1     2000          1   Kansas City Chiefs   Indianapolis Colts
# 2     2000          1  Washington Redskins    Carolina Panthers
# 3     2000          1      Atlanta Falcons  San Francisco 49ers
# 4     2000          1  Pittsburgh Steelers     Baltimore Ravens
# ...    ...        ...                  ...                  ...
# 5319  2019   Division   Kansas City Chiefs       Houston Texans
# 5320  2019   Division    Green Bay Packers     Seattle Seahawks
# 5321  2019  ConfChamp   Kansas City Chiefs     Tennessee Titans
# 5322  2019  ConfChamp  San Francisco 49ers    Green Bay Packers
# 5323  2019  SuperBowl   Kansas City Chiefs  San Francisco 49ers
#
#                    winner  tie  day         date    time  pts_win  pts_loss  \
# 0       Minnesota Vikings  NaN  Sun  September 3  1:00PM       30        27
# ...

# %%
standing_raw = pd.read_csv('../dataset/nfl_data/standings.csv')
standing_raw
# Out:
#               team  team_name  year  wins  loss  points_for  points_against  \
# 0            Miami   Dolphins  2000    11     5         323             226
# 1     Indianapolis      Colts  2000    10     6         429             326
# 2         New York       Jets  2000     9     7         321             321
# 3          Buffalo      Bills  2000     8     8         315             350
# 4      New England   Patriots  2000     5    11         276             338
# ..             ...        ...   ...   ...   ...         ...             ...
# 633       Carolina   Panthers  2019     5    11         340             470
# 634  San Francisco      49ers  2019    13     3         479             310
# 635        Seattle   Seahawks  2019    11     5         405             398
# 636    Los Angeles       Rams  2019     9     7         394             364
# 637        Arizona  Cardinals  2019     5    10         361             442
#
# ...
